# %%
#imports libraries and file
import pandas as pd
df = pd.read_csv('countries_of_the_world.csv')
pd.set_option('display.max_rows', 5000)

# %% [markdown]
# Data from https://www.kaggle.com/fernandol/countries-of-the-world
#
# ## Assess
#
# #### Column changes
# - Change columns names with spaces and capitalizations
# - GDP column per capita?
# - Change datatypes of columns with new values
# - Columns with commas instead of decimal place:
#   - Pop. Density (per sq. mi.)
#   - Coastline (coast/area ratio)
#   - Net migration
#   - Infant mortality (per 1000 births)
#   - Literacy (%)
#   - Phones (per 1000)
#   - Arable (%)
#   - Crops (%)
#   - Other (%)
#   - Birthrate
#   - Deathrate
#   - Agriculture
#   - Industry
#   - Service
#
# #### Other Changes
# - Double entry for Dem. Repub. of the Congo with different values

# %% [markdown]
# ## Clean
# #### Deletes double entry for Democratic Republic of the Congo

# %%
#drops extra row of Congo data by index number
df = df.drop([46])

# %% [markdown]
# ### Column Changes
# #### Change Column Names

# %%
#changes column names
old_names = ('Country', 'Region', 'Population', 'Area (sq. mi.)', 'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)', 'Net migration', 'Infant mortality (per 1000 births)', 'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate', 'Agriculture', 'Industry', 'Service')
new_names = ('country', 'region', 'population', 'area_sqm', 'pop_density_sqm', 'coastline_ratio', 'net_migration', 'infant_mortality_per_thousand', 'gdp', 'literacy', 'phones_per_thousand', 'arable', 'crops', 'other', 'climate', 'birthrate', 'deathrate', 'agriculture', 'industry', 'service')
df.rename(columns=dict(zip(old_names, new_names)), inplace=True)

# %% [markdown]
# #### Change Commas and Datatypes

# %%
#changes commas to periods and datatype to float
# use a loop?
df['pop_density_sqm'] = df['pop_density_sqm'].str.replace(',','.').astype(float)
df['coastline_ratio'] = df['coastline_ratio'].str.replace(',','.').astype(float)
df['net_migration'] = df['net_migration'].str.replace(',','.').astype(float)
df['infant_mortality_per_thousand'] = df['infant_mortality_per_thousand'].str.replace(',','.').astype(float)
df['literacy'] = df['literacy'].str.replace(',','.').astype(float)
df['phones_per_thousand'] = df['phones_per_thousand'].str.replace(',','.').astype(float)
df['arable'] = df['arable'].str.replace(',','.').astype(float)
df['crops'] = df['crops'].str.replace(',','.').astype(float)
df['other'] = df['other'].str.replace(',','.').astype(float)
df['birthrate'] = df['birthrate'].str.replace(',','.').astype(float)
df['deathrate'] = df['deathrate'].str.replace(',','.').astype(float)
df['agriculture'] = df['agriculture'].str.replace(',','.').astype(float)
df['industry'] = df['industry'].str.replace(',','.').astype(float)
df['service'] = df['service'].str.replace(',','.').astype(float)

# %% [markdown]
# #### Creates new column for new population change

# %%
#adds column of net population change
df['net_pop_change'] = df.birthrate - df.deathrate

# %%
df.population.mean()
# Out:
# 28851071.845132742

# %% [markdown]
# ## Analysis
# Do Countries with highest infant mortality have highest birthrates?

# %%
df.groupby('country')['birthrate'].mean()
# Malaysia                             22.86
# Maldives                             34.81
# Mali                                 49.82
# Malta                                10.22
# Marshall Islands                     33.05
# Martinique                           13.74
# Mauritania                           40.99
# Mauritius                            15.43
# Mayotte                              40.95
# Mexico                               20.69
# Micronesia, Fed. St.                 24.68
# Moldova                              15.70
# Monaco                                9.19
# Mongolia                             21.59
# Montserrat                           17.59
# Morocco                              21.98
# Mozambique                           35.18
# N. Mariana Islands                   19.43
# Namibia                              24.32
# Nauru                                24.76
# Nepal                                30.98
# Netherlands                          10.90
# Netherlands Antilles                 14.78
# New Caledonia                        18.11
# New Zealand                          13.76
# Nicaragua                            24.51
# Niger                                50.73
# Nigeria                              40.43
# Norway                               11.46
# Oman                                 36.24
# Pakistan                             29.74
# Palau                                18.03
# Panama                               21.74
# Papua New Guinea                     29.36
# Paraguay                             29.10
# Peru                                 20.48
# Philippines                          24.89
# Poland                                9.85
# Portugal                             10.72
# Puerto Rico                          12.77
# Qatar                                15.56
# Reunion                              18.90
# Romania                              10.70
# Russia                                9.95
# Rwanda                               40.37
# Saint Helena                         12.13
# Saint Kitts & Nevis                  18.02
# Saint Lucia                          19.68
# Saint Vincent and the Grenadines     16.18
# Samoa                                16.43
# San Marino                           10.02
# Sao Tome & Principe                  40.25
# Saudi Arabia                         29.34
# Senegal                              32.78
# Serbia                                 NaN
# Seychelles                           16.03
# Sierra Leone                         45.76
# Singapore                             9.34
# Slovakia                             10.65
# Slovenia                              8.98
# Solomon Islands                      30.01
# Somalia                              45.13
# South Africa                         18.20
# Spain                                10.06
# Sri Lanka                            15.51
# St Pierre & Miquelon                 13.52
# Sudan                                34.53
# Suriname                             18.02
# Swaziland                            27.41
# Sweden                               10.27
# Switzerland                           9.71
# Syria                                27.76
# Taiwan                               12.56
# Tajikistan                           32.65
# Tanzania                             37.71
# Thailand                             13.87
# Togo                                 37.01
# Tonga                                25.37
# Trinidad & Tobago                    12.90
# Tunisia                              15.52
# Turkey                               16.62
# Turkmenistan                         27.61
# Turks & Caicos Is                    21.84
# Tuvalu                               22.18
# Uganda                               47.35
# Ukraine                               8.82
# United Arab Emirates                 18.96
# United Kingdom                       10.71
# United States                        14.14
# Uruguay                              13.91
# Uzbekistan                           26.36
# Vanuatu                              22.72
# Venezuela                            18.71
# Vietnam                              16.86
# Virgin Islands                       13.96
# Wallis and Futuna                      NaN
# West Bank                            31.67
# Western Sahara                         NaN
# Yemen                                42.89
# Zambia                               41.00
# Zimbabwe                             28.01
# Name: birthrate, dtype: float64

# %%
df.groupby('country')['infant_mortality_per_thousand'].mean()
# Out:
# country
# Afghanistan                          163.07
# Albania                               21.52
# Algeria                               31.00
# American Samoa                         9.27
# Andorra                                4.05
# Angola                               191.19
# Anguilla                              21.03
# Antigua & Barbuda                     19.46
# Argentina                             15.18
# Armenia                               23.28
# Aruba                                  5.89
# Australia                              4.69
# Austria                                4.66
# Azerbaijan                            81.74
# Bahamas, The                          25.21
# Bahrain                               17.27
# Bangladesh                            62.60
# Mozambique                           130.79
# N. Mariana Islands                     7.11
# Namibia                               48.98
# Nauru                                  9.95
# Nepal                                 66.98
# Netherlands                            5.04
# Netherlands Antilles                  10.03
# New Caledonia                          7.72
# New Zealand                            5.85
# Nicaragua                             29.11
# Niger                                121.69
# Nigeria                               98.80
# Norway                                 3.70
# Oman                                  19.51
# Pakistan                              72.44
# Palau                                 14.84
# Panama                                20.47
# Papua New Guinea                      51.45
# Paraguay                              25.63
# Peru                                  31.94
# Philippines                           23.51
# Poland                                 8.51
# Portugal                               5.05
# Puerto Rico                            8.24
# Qatar                                 18.61
# Reunion                                7.78
# Romania                               26.43
# Russia                                15.39
# Rwanda                                91.23
# Saint Helena                          19.00
# Saint Kitts & Nevis                   14.49
# Saint Lucia                           13.53
# Saint Vincent and the Grenadines      14.78
# Samoa                                 27.71
# San Marino                             5.73
# Sao Tome & Principe                   43.11
# Saudi Arabia                          13.24
# Senegal                               55.51
# Serbia                                12.89
# Seychelles                            15.53
# Sierra Leone                         143.64
# Singapore                              2.29
# Slovakia                               7.41
# Slovenia                               4.45
# Solomon Islands                       21.29
# Somalia                              116.70
# South Africa                          61.81
# Spain                                  4.42
# Sri Lanka                             14.35
# St Pierre & Miquelon                   7.54
# Sudan                                 62.50
# Suriname                              23.57
# Swaziland                             69.27
# Sweden                                 2.77
# Switzerland                            4.39
# Syria                                 29.53
# Taiwan                                 6.40
# Tajikistan                           110.76
# Tanzania                              98.54
# Thailand                              20.48
# Togo                                  66.61
# Tonga                                 12.62
# Trinidad & Tobago                     24.31
# Tunisia                               24.77
# Turkey                                41.04
# Turkmenistan                          73.08
# Turks & Caicos Is                     15.67
# Tuvalu                                20.03
# Uganda                                67.83
# Ukraine                               20.34
# United Arab Emirates                  14.51
# United Kingdom                         5.16
# United States                          6.50
# Uruguay                               11.95
# Uzbekistan                            71.10
# Vanuatu                               55.16
# Venezuela                             22.20
# Vietnam                               25.95
# Virgin Islands                         8.03
# Wallis and Futuna                       NaN
# West Bank                             19.62
# Western Sahara                          NaN
# Yemen                                 61.50
# Zambia                                88.29
# Zimbabwe                              67.69
# Name: infant_mortality_per_thousand, dtype: float64

# %%
#writes code to csv
df.to_csv('country_data.csv')

# %% [markdown]
# ### References
#
# - https://www.kaggle.com/fernandol/countries-of-the-world
# - https://en.wikipedia.org/wiki/Birth_rate
# - https://stackoverflow.com/questions/38101009/changing-multiple-column-names-but-not-all-of-them-panda-python
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
# - https://erikrood.com/Python_References/dropping_rows_cols_pandas.html
# - https://www.google.com/publicdata/explore?ds=d5bncppjof8f9_&met_y=sp_pop_totl&hl=en&dl=en#!ctype=l&strail=false&bcs=d&nselm=h&met_y=sp_pop_totl&scale_y=lin&ind_y=false&rdim=region&idim=country:COG&ifdim=region&tdim=true&hl=en_US&dl=en&ind=false
# - https://countryeconomy.com/demography/literacy-rate/democratic-republic-congo
# - https://en.wikipedia.org/wiki/Democratic_Republic_of_the_Congo
